# %%
import torch
import speech_recognition as sr
from time import time

# %%
# # 📦 Step 1: Import dependencies
# from pydub import AudioSegment
# from pydub.utils import which
# from pathlib import Path

# # 📍 Step 2: Check if FFmpeg is available
# ffmpeg_path = which("ffmpeg")
# if ffmpeg_path is None:
#     print("❌ FFmpeg not found. Please install it and add it to PATH.")
# else:
#     print(f"✅ FFmpeg found at: {ffmpeg_path}")

# # 🛠️ Step 3: Conversion function
# def convert_mp3_to_wav(folder_path):
#     folder = Path(folder_path)
#     mp3_files = list(folder.glob("*.mp3")) + list(folder.glob("*.MP3"))

#     if not mp3_files:
#         print(f"❌ No .mp3 files found in: {folder}")
#         return

#     for mp3_file in mp3_files:
#         print(f"🎧 Converting: {mp3_file.name}")
#         try:
#             wav_file = mp3_file.with_suffix(".wav")
#             audio = AudioSegment.from_mp3(mp3_file)
#             audio = audio.set_channels(1).set_frame_rate(16000)
#             audio.export(wav_file, format="wav")
#             print(f"✅ Converted: {mp3_file.name} → {wav_file.name}")
#         except Exception as e:
#             print(f"⚠️ Error converting {mp3_file.name}: {e}")

# # 🚀 Step 4: Run it on your specific folder
# convert_mp3_to_wav(r"C:\Users\admin\Desktop\BEA-Capstone\data\speech_wpm")

# %%
# Transcribe & Compute WPM
import speech_recognition as sr
import pandas as pd
from pathlib import Path

def process_audio_folder(folder_path):
    recognizer = sr.Recognizer()
    results = []
    folder = Path(folder_path)

    wav_files = list(folder.glob("*.wav"))
    print(f"🔍 Found {len(wav_files)} .wav files in: {folder.resolve()}")

    for wav_file in wav_files:
        print(f"🎧 Processing: {wav_file.name}")
        try:
            with sr.AudioFile(str(wav_file)) as source:
                audio = recognizer.record(source)

                # Calculate duration manually (fallback for missing .DURATION)
                duration_sec = len(audio.frame_data) / (audio.sample_rate * audio.sample_width)
                print(f"⏱️ Duration: {duration_sec:.2f} seconds")

            # Taglish transcription using Google Speech API
            text = recognizer.recognize_google(audio, language="en-PH")
            word_count = len(text.split())
            wpm = word_count / (duration_sec / 60)

            results.append({
                "filename": wav_file.name,
                "transcription": text,
                "duration_sec": duration_sec,
                "word_count": word_count,
                "wpm": wpm,
                "label": None  # optional for later ADHD labeling
            })

            print(f"✅ WPM: {wpm:.2f} — {text}")

        except sr.UnknownValueError:
            print(f"❌ No speech recognized in {wav_file.name}")
        except sr.RequestError as e:
            print(f"❌ Google API Error: {e}")
        except Exception as e:
            print(f"⚠️ Error with {wav_file.name}: {e}")

    # Save to CSV
    df = pd.DataFrame(results)
    print(f"\n🧾 Transcribed {len(df)} files.")
    df.to_csv("rapid_talking_data.csv", index=False)
    return df

df = process_audio_folder(r"C:\Users\admin\Desktop\BEA-Capstone\data\speech_wpm")
# Out:
# 🔍 Found 163 .wav files in: C:\Users\admin\Desktop\BEA-Capstone\data\speech_wpm
# 🎧 Processing: r1.wav
# ⏱️ Duration: 4.09 seconds
# ✅ WPM: 146.82 — ma tapos na ako oh tignan mo ang ganda diba
# 🎧 Processing: r10.wav
# ⏱️ Duration: 3.13 seconds
# ✅ WPM: 133.98 — kuroko drawing ko ito akong gumawa lahat
# 🎧 Processing: r100.wav
# ⏱️ Duration: 3.95 seconds
# ✅ WPM: 91.22 — bakit siya may sticker ako wala
# 🎧 Processing: r101.wav
# ⏱️ Duration: 3.56 seconds
# ✅ WPM: 84.21 — nakakatakot yung tunog ano yun
# 🎧 Processing: r102.wav
# ⏱️ Duration: 3.52 seconds
# ✅ WPM: 102.27 — naubos ko na pwede dagdag ulit
# 🎧 Processing: r103.wav
# ⏱️ Duration: 4.33 seconds
# ✅ WPM: 138.55 — huwag mo gagalaw niyan ah inayos ko na yan eh
# 🎧 Processing: r104.wav
# ⏱️ Duration: 3.82 seconds
# ✅ WPM: 78.56 — kanina tong ballpen pwede pahiram
# 🎧 Processing: r105.wav
# ⏱️ Duration: 3.97 seconds
# ✅ WPM: 75.60 — ang tagal mag-load ayoko na
# 🎧 Processing: r106.wav
# ⏱️ Duration: 3.69 seconds
# ✅ WPM: 113.80 — gusto ko upo sa lap mo ma
# 🎧 Processing: r107.wav
# ⏱️ Duration: 4.12 seconds
# ✅ WPM: 116.58 — nasaan si doc diba sabi niya babalik siya
# 🎧 Processing: r108.wav
# ⏱️ Duration: 4.10 seconds
# ✅ WPM: 102.54 — ayaw ko nito ayoko talaga ng ganito
# 🎧 Processing: r109.wav
# ⏱️ Duration: 3.75 seconds
# ✅ WPM: 95.88 — tignan mo may drawing sa wall
# 🎧 Processing: r11.wav
# ⏱️ Duration: 4.02 seconds
# ✅ WPM: 134.43 — wait mo ako ha mag cr lang ako saglit
# 🎧 Processing: r110.wav
# ⏱️ Duration: 4.50 seconds
# ✅ WPM: 106.63 — kailan na ulit ito gusto ko pumunta ulit
# 🎧 Processing: r111.wav
# ⏱️ Duration: 4.03 seconds
# ✅ WPM: 104.17 — ang cute ng shoes mo pwede pahiram
# 🎧 Processing: r112.wav
# ⏱️ Duration: 3.78 seconds
# ✅ WPM: 95.34 — my name tag ako galing diba
# 🎧 Processing: r113.wav
# ⏱️ Duration: 4.35 seconds
# ✅ WPM: 110.29 — sabi mo saglit lang ang tagal mo na
# 🎧 Processing: r114.wav
# ⏱️ Duration: 4.82 seconds
# ✅ WPM: 99.56 — hindi ko na maalala pero ginawa ko yun
# 🎧 Processing: r115.wav
# ⏱️ Duration: 4.14 seconds
# ✅ WPM: 86.98 — naglalaro lang ako tapos biglang nasira
# 🎧 Processing: r116.wav
# ⏱️ Duration: 3.69 seconds
# ✅ WPM: 113.80 — pwede bang ako mag press ng button
# 🎧 Processing: r117.wav
# ⏱️ Duration: 4.20 seconds
# ✅ WPM: 99.94 — huwag mo i-off yan pinapanood ko pa
# 🎧 Processing: r118.wav
# ⏱️ Duration: 3.84 seconds
# ✅ WPM: 109.38 — ang dami kong nasulat look tingnan mo
# 🎧 Processing: r119.wav
# ⏱️ Duration: 3.71 seconds
# ✅ WPM: 113.15 — gusto ko ng music yung pang dance
# 🎧 Processing: r12.wav
# ⏱️ Duration: 2.48 seconds
# ✅ WPM: 144.89 — wala akong ginawa siya yung nag-start
# 🎧 Processing: r120.wav
# ⏱️ Duration: 4.14 seconds
# ✅ WPM: 86.98 — ayoko ng quiet ang lungkot eh
# 🎧 Processing: r121.wav
# ⏱️ Duration: 4.91 seconds
# ✅ WPM: 110.05 — mama ikaw na lang magsabi kay doc nahihiya ako
# 🎧 Processing: r122.wav
# ⏱️ Duration: 4.52 seconds
# ✅ WPM: 39.80 — masakit tuhod ko
# 🎧 Processing: r123.wav
# ⏱️ Duration: 5.85 seconds
# ✅ WPM: 92.38 — gusto ko ice cream yung chocolate with sprinkle please
# 🎧 Processing: r124.wav
# ⏱️ Duration: 4.48 seconds
# ✅ WPM: 93.75 — can i play with kuya sa labas
# 🎧 Processing: r125.wav
# ⏱️ Duration: 4.80 seconds
# ✅ WPM: 100.00 — nasaan si ate sabi niya pupunta siya dito
# 🎧 Processing: r126.wav
# ⏱️ Duration: 4.52 seconds
# ✅ WPM: 92.87 — hindi ko sinasadya promise nahulog lang bigla
# 🎧 Processing: r127.wav
# ⏱️ Duration: 4.10 seconds
# ✅ WPM: 117.19 — ayoko na pagod na ako tapos gutom pa
# 🎧 Processing: r128.wav
# ⏱️ Duration: 4.85 seconds
# ✅ WPM: 98.99 — what's the cartoons yung blue dog si bluey
# 🎧 Processing: r129.wav
# ⏱️ Duration: 6.44 seconds
# ✅ WPM: 37.25 — loko drawing ko ito
# 🎧 Processing: r13.wav
# ⏱️ Duration: 4.83 seconds
# ✅ WPM: 86.96 — laro tayo dali na taguan or ambulan
# 🎧 Processing: r130.wav
# ⏱️ Duration: 4.10 seconds
# ❌ No speech recognized in r130.wav
# 🎧 Processing: r131.wav
# ⏱️ Duration: 3.78 seconds
# ❌ No speech recognized in r131.wav
# 🎧 Processing: r132.wav
# ⏱️ Duration: 3.56 seconds
# ✅ WPM: 101.05 — wala akong ginawa siya yung nag-start
# 🎧 Processing: r133.wav
# ⏱️ Duration: 4.44 seconds
# ✅ WPM: 108.17 — mama i'm hungry now kain na tayo please
# 🎧 Processing: r134.wav
# ⏱️ Duration: 3.95 seconds
# ✅ WPM: 121.62 — hindi ko gets to paano gawin itong puzzle
# 🎧 Processing: r135.wav
# ⏱️ Duration: 3.61 seconds
# ✅ WPM: 133.13 — nakita mo yung toy ko yung may ilaw
# 🎧 Processing: r136.wav
# ⏱️ Duration: 4.84 seconds
# ✅ WPM: 111.51 — diba sabi mo later na lang bakit ngayon na
# 🎧 Processing: r137.wav
# ⏱️ Duration: 5.01 seconds
# ✅ WPM: 95.74 — i miss you papa tagal na niyang wala
# 🎧 Processing: r138.wav
# ⏱️ Duration: 3.82 seconds
# ✅ WPM: 109.99 — let's go na bilis baka maubusan tayo
# 🎧 Processing: r139.wav
# ⏱️ Duration: 4.46 seconds
# ✅ WPM: 134.57 — hello po ang galing ko diba ako lang gumawa nito
# 🎧 Processing: r14.wav
# ⏱️ Duration: 3.58 seconds
# ✅ WPM: 134.23 — ay nabasag ko yata yung cap ni mama
# 🎧 Processing: r140.wav
# ⏱️ Duration: 4.25 seconds
# ✅ WPM: 113.06 — can i use the phone promise saglit lang
# 🎧 Processing: r141.wav
# ⏱️ Duration: 5.76 seconds
# ✅ WPM: 93.75 — promise hindi ko na uulitin last na talaga yun
# 🎧 Processing: r142.wav
# ⏱️ Duration: 3.75 seconds
# ✅ WPM: 127.84 — ang bilis niya tumakbo parang flash o sonic
# 🎧 Processing: r143.wav
# ⏱️ Duration: 4.91 seconds
# ✅ WPM: 110.05 — ma tapos na ako tignan mo ang ganda diba
# 🎧 Processing: r144.wav
# ⏱️ Duration: 4.76 seconds
# ✅ WPM: 88.28 — laro tayo dali na taguan o habulan
# 🎧 Processing: r145.wav
# ⏱️ Duration: 4.25 seconds
# ✅ WPM: 113.06 — ay nabasag ko yata yung cap ni mama
# 🎧 Processing: r146.wav
# ⏱️ Duration: 3.71 seconds
# ✅ WPM: 145.47 — can i have candy now kahit isa lang po
# 🎧 Processing: r147.wav
# ⏱️ Duration: 4.52 seconds
# ✅ WPM: 106.13 — no na siya eh unfair ako dapat first
# 🎧 Processing: r148.wav
# ⏱️ Duration: 3.86 seconds
# ✅ WPM: 139.85 — ako din gusto ko rin noon yung may sound
# 🎧 Processing: r149.wav
# ⏱️ Duration: 5.03 seconds
# ✅ WPM: 119.17 — ang cute ng doggy kanina sa labas maliit lang siya
# 🎧 Processing: r15.wav
# ⏱️ Duration: 3.11 seconds
# ✅ WPM: 154.27 — mama i'm hungry na kain na tayo please
# 🎧 Processing: r150.wav
# ⏱️ Duration: 4.29 seconds
# ✅ WPM: 111.94 — tulog na si baby pwede ko siya gisingin
# 🎧 Processing: r151.wav
# ⏱️ Duration: 6.23 seconds
# ✅ WPM: 105.95 — huwag mong kunin yan ah akin yan eh binigay ni lola
# 🎧 Processing: r152.wav
# ⏱️ Duration: 4.80 seconds
# ✅ WPM: 50.00 — ang haba ng buntot
# 🎧 Processing: r153.wav
# ⏱️ Duration: 4.25 seconds
# ✅ WPM: 113.06 — hindi ko gusto ito lasang yaki pwede palitan
# 🎧 Processing: r154.wav
# ⏱️ Duration: 4.22 seconds
# ✅ WPM: 99.41 — ayoko na mag-toothbrush pagod na ako eh
# 🎧 Processing: r155.wav
# ⏱️ Duration: 4.54 seconds
# ✅ WPM: 118.84 — dito ka lang ha mag aalis takot akong mag-isa
# 🎧 Processing: r156.wav
# ⏱️ Duration: 4.74 seconds
# ✅ WPM: 101.35 — ay nasaan si kuya dito lang siya kanina
# 🎧 Processing: r157.wav
# ⏱️ Duration: 4.50 seconds
# ❌ No speech recognized in r157.wav
# 🎧 Processing: r158.wav
# ⏱️ Duration: 5.12 seconds
# ✅ WPM: 105.47 — hala may sugat ako ang sakit may dugo pa
# 🎧 Processing: r159.wav
# ⏱️ Duration: 4.12 seconds
# ✅ WPM: 102.01 — let's go na bilis baka maubusan tayo
# 🎧 Processing: r16.wav
# ⏱️ Duration: 3.78 seconds
# ✅ WPM: 127.12 — tapos na akong mag color galing ko no
# 🎧 Processing: r160.wav
# ⏱️ Duration: 4.48 seconds
# ✅ WPM: 93.75 — why siomai toy ako wala di fare
# 🎧 Processing: r161.wav
# ⏱️ Duration: 4.46 seconds
# ✅ WPM: 94.20 — ako mag-isa lang sa room kanina nakakatakot
# 🎧 Processing: r162.wav
# ⏱️ Duration: 3.86 seconds
# ✅ WPM: 124.31 — tapos na ba yung rain pwede na mag-bike
# 🎧 Processing: r163.wav
# ⏱️ Duration: 4.05 seconds
# ✅ WPM: 133.22 — ang gulo mo kuya sinira mo yung lego ko
# 🎧 Processing: r17.wav
# ⏱️ Duration: 3.99 seconds
# ✅ WPM: 120.32 — kuya ang bilis mo hintayin mo naman ako
# 🎧 Processing: r18.wav
# ⏱️ Duration: 3.58 seconds
# ✅ WPM: 134.23 — nakita mo yung toy ko yung may ilaw
# 🎧 Processing: r19.wav
# ⏱️ Duration: 4.18 seconds
# ✅ WPM: 71.78 — unfair ako ang dapat first
# 🎧 Processing: r2.wav
# ⏱️ Duration: 3.53 seconds
# ✅ WPM: 102.00 — ay nadapa ako masakit tuhod ko
# 🎧 Processing: r20.wav
# ⏱️ Duration: 3.85 seconds
# ✅ WPM: 124.53 — ako din gusto ko rin yung may sound
# 🎧 Processing: r21.wav
# ⏱️ Duration: 3.85 seconds
# ✅ WPM: 155.66 — can i have a candy now kahit isa lang po
# 🎧 Processing: r22.wav
# ⏱️ Duration: 3.34 seconds
# ✅ WPM: 143.55 — hindi ko gets to paano gawin itong pu
# 🎧 Processing: r23.wav
# ⏱️ Duration: 9.37 seconds
# ✅ WPM: 64.07 — ang cute ng doggy kanina sa labas maliit lang siya
# 🎧 Processing: r24.wav
# ⏱️ Duration: 5.91 seconds
# ✅ WPM: 81.23 — tulog na si baby pwede ko siyang gisingin
# 🎧 Processing: r25.wav
# ⏱️ Duration: 9.75 seconds
# ✅ WPM: 61.54 — huwag mong kuhanin yan akin yan eh binigay ni lola
# 🎧 Processing: r26.wav
# ⏱️ Duration: 5.61 seconds
# ✅ WPM: 96.24 — i'm a lizard sa wall ang haba ng buntot
# 🎧 Processing: r27.wav
# ⏱️ Duration: 6.29 seconds
# ✅ WPM: 76.27 — diba sabi mo later lang bakit ngayon na
# 🎧 Processing: r28.wav
# ⏱️ Duration: 5.44 seconds
# ✅ WPM: 88.24 — i miss si papa tagal niya ng wala
# 🎧 Processing: r29.wav
# ⏱️ Duration: 6.29 seconds
# ✅ WPM: 95.34 — hala may sugat ako o ang sakit may dugo pa
# 🎧 Processing: r3.wav
# ⏱️ Duration: 4.46 seconds
# ✅ WPM: 121.12 — gusto kong ice cream yung chocolate with sprinkles please
# 🎧 Processing: r30.wav
# ⏱️ Duration: 6.06 seconds
# ✅ WPM: 69.32 — let's go na bilis baka maubusan tayo
# 🎧 Processing: r31.wav
# ⏱️ Duration: 6.72 seconds
# ✅ WPM: 89.29 — look o ang galing ko diba ako lang gumawa nito
# 🎧 Processing: r32.wav
# ⏱️ Duration: 6.93 seconds
# ✅ WPM: 51.92 — why siomai toy ako wala differ
# 🎧 Processing: r33.wav
# ⏱️ Duration: 6.81 seconds
# ✅ WPM: 61.72 — ako mag-isa lang sa room kanina nakakatakot
# 🎧 Processing: r34.wav
# ⏱️ Duration: 7.21 seconds
# ✅ WPM: 74.89 — can i use the phone promise saglit lang talaga
# 🎧 Processing: r35.wav
# ⏱️ Duration: 7.38 seconds
# ✅ WPM: 73.16 — tapos na ba yung rain pwede na ba mag-bike
# 🎧 Processing: r36.wav
# ⏱️ Duration: 7.17 seconds
# ✅ WPM: 75.33 — ang gulo mo kuya sinira mo yung lego ko
# 🎧 Processing: r37.wav
# ⏱️ Duration: 5.42 seconds
# ✅ WPM: 88.58 — promise hindi ko uulitin last na talaga iyon
# 🎧 Processing: r38.wav
# ⏱️ Duration: 8.49 seconds
# ✅ WPM: 84.80 — dito ka lang ha huwag kang huwag kang aalis takot ako mag-isa
# 🎧 Processing: r39.wav
# ⏱️ Duration: 7.68 seconds
# ✅ WPM: 62.50 — ay nasaan si kuya dito lang siya kanina
# 🎧 Processing: r4.wav
# ⏱️ Duration: 3.83 seconds
# ✅ WPM: 125.28 — can i play na with kuya sa labas
# 🎧 Processing: r40.wav
# ⏱️ Duration: 5.76 seconds
# ✅ WPM: 83.33 — ang bilis niya tumakbo parang flash o sonic
# 🎧 Processing: r41.wav
# ⏱️ Duration: 5.76 seconds
# ✅ WPM: 72.92 — ayoko na mag-toothbrush pagod na ako eh
# 🎧 Processing: r42.wav
# ⏱️ Duration: 6.91 seconds
# ✅ WPM: 69.44 — hindi ko gusto ito lasang yaki pwedeng palitan
# 🎧 Processing: r43.wav
# ⏱️ Duration: 7.48 seconds
# ❌ No speech recognized in r43.wav
# 🎧 Processing: r44.wav
# ⏱️ Duration: 4.78 seconds
# ✅ WPM: 112.89 — nigga tapos na ako tignan mo ang ganda diba
# 🎧 Processing: r45.wav
# ⏱️ Duration: 4.55 seconds
# ✅ WPM: 79.10 — ay nadapa ako masakit tuhod ko
# 🎧 Processing: r46.wav
# ⏱️ Duration: 6.11 seconds
# ✅ WPM: 98.25 — gusto ko yung ice cream yung chocolate with sprinkle please
# 🎧 Processing: r47.wav
# ⏱️ Duration: 4.37 seconds
# ✅ WPM: 109.96 — can i play now with kuya sa labas
# 🎧 Processing: r48.wav
# ⏱️ Duration: 4.55 seconds
# ✅ WPM: 105.47 — nasaan si ate sabi niya pupunta siya dito
# 🎧 Processing: r49.wav
# ⏱️ Duration: 4.95 seconds
# ✅ WPM: 84.92 — hindi ko sinasadya promise nahulog lang bigla
# 🎧 Processing: r5.wav
# ⏱️ Duration: 4.71 seconds
# ✅ WPM: 101.83 — nasaan si ate sabi niya pupunta siya dito
# 🎧 Processing: r50.wav
# ⏱️ Duration: 5.64 seconds
# ✅ WPM: 85.07 — ayoko na pagod na ako tapos gutom pa
# 🎧 Processing: r51.wav
# ⏱️ Duration: 5.29 seconds
# ✅ WPM: 90.67 — watch tayo cartoons yung blue dog si bluey
# 🎧 Processing: r52.wav
# ⏱️ Duration: 4.76 seconds
# ✅ WPM: 113.44 — teka lang ha may naiwan akong toy sa room
# 🎧 Processing: r53.wav
# ⏱️ Duration: 4.76 seconds
# ✅ WPM: 100.84 — look a drawing ko ito ako gumawa lahat
# 🎧 Processing: r54.wav
# ⏱️ Duration: 4.11 seconds
# ✅ WPM: 116.79 — wait mo ako ha mag cr lang saglit
# 🎧 Processing: r55.wav
# ⏱️ Duration: 4.55 seconds
# ✅ WPM: 79.10 — wala akong ginawa sa iyong nag-start
# 🎧 Processing: r56.wav
# ⏱️ Duration: 5.60 seconds
# ✅ WPM: 64.33 — laro tayo dalina taguan or habulan
# 🎧 Processing: r57.wav
# ⏱️ Duration: 4.32 seconds
# ✅ WPM: 111.14 — ay nabasag ko yata yung cap ni mama
# 🎧 Processing: r58.wav
# ⏱️ Duration: 6.66 seconds
# ✅ WPM: 63.02 — mama i'm hungry na kain tayo please
# 🎧 Processing: r59.wav
# ⏱️ Duration: 5.02 seconds
# ✅ WPM: 107.67 — can i have candy now kahit isa lang po
# 🎧 Processing: r6.wav
# ⏱️ Duration: 3.67 seconds
# ✅ WPM: 114.48 — hindi ko sinasadya promise nahulog lang bigla
# 🎧 Processing: r60.wav
# ⏱️ Duration: 5.02 seconds
# ✅ WPM: 47.85 — paano gawin itong puzzle
# 🎧 Processing: r61.wav
# ⏱️ Duration: 4.32 seconds
# ✅ WPM: 111.14 — nakita mo yung toy ko yung may ilaw
# 🎧 Processing: r62.wav
# ⏱️ Duration: 4.64 seconds
# ✅ WPM: 77.52 — nauna say unfair ako dapat first
# 🎧 Processing: r63.wav
# ⏱️ Duration: 5.87 seconds
# ✅ WPM: 91.92 — ako rin gusto ko rin noon yung may sound
# 🎧 Processing: r64.wav
# ⏱️ Duration: 4.76 seconds
# ✅ WPM: 126.05 — ang cute ng doggy kanina sa labas maliit lang siya
# 🎧 Processing: r65.wav
# ⏱️ Duration: 4.67 seconds
# ✅ WPM: 102.84 — tulog na si baby pwede ko siya gisingin
# 🎧 Processing: r66.wav
# ⏱️ Duration: 5.18 seconds
# ✅ WPM: 115.87 — huwag mo kuhanin iyan akin iyan eh binigay ni lola
# 🎧 Processing: r67.wav
# ⏱️ Duration: 5.46 seconds
# ✅ WPM: 120.95 — i'm a lizard sa wall ang haba ng buntot tang ina
# 🎧 Processing: r68.wav
# ⏱️ Duration: 6.36 seconds
# ✅ WPM: 66.01 — hindi ko gusto lasang yaki pwede palitan
# 🎧 Processing: r69.wav
# ⏱️ Duration: 3.92 seconds
# ✅ WPM: 107.03 — ayoko na mag-toothbrush pagod na ako eh
# 🎧 Processing: r7.wav
# ⏱️ Duration: 3.60 seconds
# ✅ WPM: 133.37 — ayoko na pagod na ako tapos gutom pa
# 🎧 Processing: r70.wav
# ⏱️ Duration: 4.81 seconds
# ✅ WPM: 99.86 — diba sabi mo later lang bakit ngayon na
# 🎧 Processing: r71.wav
# ⏱️ Duration: 5.04 seconds
# ✅ WPM: 95.26 — i miss si papa tagal na niyang nawala
# 🎧 Processing: r72.wav
# ⏱️ Duration: 6.13 seconds
# ✅ WPM: 88.09 — hello may sugat ako ang sakit may dugo pa
# 🎧 Processing: r73.wav
# ⏱️ Duration: 5.67 seconds
# ✅ WPM: 95.31 — let's go na bilis baka malabas na na tayo
# 🎧 Processing: r74.wav
# ⏱️ Duration: 5.97 seconds
# ✅ WPM: 100.54 — loko nigga ang galing ko diba ako lang gumawa nito
# 🎧 Processing: r75.wav
# ⏱️ Duration: 6.73 seconds
# ✅ WPM: 71.28 — why siomai toy ako wala di fair beats
# 🎧 Processing: r76.wav
# ⏱️ Duration: 6.01 seconds
# ✅ WPM: 79.81 — ako lang mag-isa sa room kanina nagjajakol nakakatakot
# 🎧 Processing: r77.wav
# ⏱️ Duration: 4.39 seconds
# ✅ WPM: 123.05 — can i use the phone promise saglit lang talaga
# 🎧 Processing: r78.wav
# ⏱️ Duration: 4.41 seconds
# ✅ WPM: 108.80 — tapos na ba yung rain pwede na mag-bike
# 🎧 Processing: r79.wav
# ⏱️ Duration: 4.46 seconds
# ✅ WPM: 121.12 — ang gulo mo kuya sinira mo yung lego ko
# 🎧 Processing: r8.wav
# ⏱️ Duration: 5.06 seconds
# ✅ WPM: 106.68 — march tayo ng cartoon yung blue dog si bluey
# 🎧 Processing: r80.wav
# ⏱️ Duration: 5.67 seconds
# ✅ WPM: 95.31 — promise di ko na uulitin last na talaga yun
# 🎧 Processing: r81.wav
# ⏱️ Duration: 5.99 seconds
# ✅ WPM: 90.14 — dito ka lang ha mag aalis takot ako mag-isa
# 🎧 Processing: r82.wav
# ⏱️ Duration: 4.41 seconds
# ✅ WPM: 108.80 — ay nasaan si kuya dito lang siya kanina
# 🎧 Processing: r83.wav
# ⏱️ Duration: 5.43 seconds
# ✅ WPM: 110.43 — ang bilis naman niya tumakbo parang si flash o sonic
# 🎧 Processing: r84.wav
# ⏱️ Duration: 4.44 seconds
# ✅ WPM: 108.17 — ay ang daming bubbles pwede ko pang hawakan
# 🎧 Processing: r85.wav
# ⏱️ Duration: 4.07 seconds
# ✅ WPM: 88.35 — may nakita akong butterfly ang ganda
# 🎧 Processing: r86.wav
# ⏱️ Duration: 2.86 seconds
# ✅ WPM: 104.94 — saan tayo pupunta after nito
# 🎧 Processing: r87.wav
# ⏱️ Duration: 3.52 seconds
# ✅ WPM: 119.32 — bakit ang tagal gusto ko na umuwi
# 🎧 Processing: r88.wav
# ⏱️ Duration: 4.03 seconds
# ✅ WPM: 119.05 — ako ulit please gusto ko gawin ulit ito
# 🎧 Processing: r89.wav
# ⏱️ Duration: 3.99 seconds
# ✅ WPM: 105.28 — ang init dito pwede tanggalin jacket ko
# 🎧 Processing: r9.wav
# ⏱️ Duration: 4.32 seconds
# ✅ WPM: 125.03 — teka lang ha may naiwan akong toy sa room
# 🎧 Processing: r90.wav
# ⏱️ Duration: 3.41 seconds
# ✅ WPM: 105.47 — may narinig akong sound ano yun
# 🎧 Processing: r91.wav
# ⏱️ Duration: 4.33 seconds
# ✅ WPM: 110.84 — hindi ko sinasadya nabangga ko lang ng konti
# 🎧 Processing: r92.wav
# ⏱️ Duration: 3.90 seconds
# ✅ WPM: 92.21 — nagugutom na ako may baon ka
# 🎧 Processing: r93.wav
# ⏱️ Duration: 3.80 seconds
# ✅ WPM: 126.40 — hala nakalimutan ko yung toy ko sa bag
# 🎧 Processing: r94.wav
# ⏱️ Duration: 3.54 seconds
# ✅ WPM: 101.66 — ang kulit ni kuya ay tumigil
# 🎧 Processing: r95.wav
# ⏱️ Duration: 3.35 seconds
# ✅ WPM: 143.31 — ako na lang mag-ayos niyan kaya ko to
# 🎧 Processing: r96.wav
# ⏱️ Duration: 4.33 seconds
# ✅ WPM: 96.98 — ma ilang minutes pa tagal na eh
# 🎧 Processing: r97.wav
# ⏱️ Duration: 3.69 seconds
# ✅ WPM: 113.80 — gusto ko ng water pwede po nauna
# 🎧 Processing: r98.wav
# ⏱️ Duration: 4.31 seconds
# ✅ WPM: 97.46 — ay lumipad yung paper ko akin yun
# 🎧 Processing: r99.wav
# ⏱️ Duration: 4.12 seconds
# ✅ WPM: 102.01 — ako ang panalo diba ako yung fastest
#
# 🧾 Transcribed 159 files.

# %%
df = pd.read_csv("rapid_talking_data.csv")
df["label"] = [1 if wpm > 100 else 0 for wpm in df["wpm"]]
df["label"] = df["label"].astype(int)

print(f"DataFrame shape: {df.shape}")
print(df.head())
print(df.isna().sum())
# Out:
# DataFrame shape: (159, 6)
#    filename                                transcription  duration_sec  \
# 0    r1.wav  ma tapos na ako oh tignan mo ang ganda diba      4.086750
# 1   r10.wav     kuroko drawing ko ito akong gumawa lahat      3.134688
# 2  r100.wav              bakit siya may sticker ako wala      3.946687
# 3  r101.wav               nakakatakot yung tunog ano yun      3.562688
# 4  r102.wav               naubos ko na pwede dagdag ulit      3.520000
#
#    word_count         wpm  label
# 0          10  146.815930      1
# 1           7  133.984648      1
# 2           6   91.215735      0
# 3           5   84.206094      0
# 4           6  102.272727      1
# filename         0
# transcription    0
# duration_sec     0
# word_count       0
# wpm              0
# label            0
# dtype: int64

# %%
#Creating Dataset and Model

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

class WPMSpeechDataset(Dataset):
    def __init__(self, df):
        self.data = torch.tensor(df["wpm"].values, dtype=torch.float32).view(-1, 1, 1)
        self.labels = torch.tensor(df["label"].values, dtype=torch.float32).view(-1, 1)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

dataset = WPMSpeechDataset(df)
loader = DataLoader(dataset, batch_size=8, shuffle=True)

class WPMLSTM(nn.Module):
    def __init__(self):
        super(WPMLSTM, self).__init__()
        self.lstm = nn.LSTM(1, 16, batch_first=True)
        self.fc = nn.Linear(16, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        return torch.sigmoid(self.fc(out[:, -1, :]))

model = WPMLSTM()
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Subset

# Split dataset into training and validation
train_idx, val_idx = train_test_split(range(len(dataset)), test_size=0.2, shuffle=True, random_state=42)
train_loader = DataLoader(Subset(dataset, train_idx), batch_size=8, shuffle=True)
val_loader = DataLoader(Subset(dataset, val_idx), batch_size=8)

# Updated Training Loop
for epoch in range(20):
    model.train()
    total_loss = 0
    correct = 0
    total = 0

    for X, y in train_loader:
        optimizer.zero_grad()
        pred = model(X)
        loss = criterion(pred, y)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        # Accuracy calculation
        predicted = (pred > 0.5).float()
        correct += (predicted == y).sum().item()
        total += y.size(0)

    acc = correct / total

    # Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_loss = 0

    with torch.no_grad():
        for X_val, y_val in val_loader:
            val_pred = model(X_val)
            val_loss += criterion(val_pred, y_val).item()
            val_predicted = (val_pred > 0.5).float()
            val_correct += (val_predicted == y_val).sum().item()
            val_total += y_val.size(0)

    val_acc = val_correct / val_total
    val_loss /= len(val_loader)

    print(f"Epoch {epoch+1}: "
          f"Train Loss = {total_loss:.4f}, Train Acc = {acc:.4f}, "
          f"Val Loss = {val_loss:.4f}, Val Acc = {val_acc:.4f}")
# Out:
# Epoch 1: Train Loss = 11.1311, Train Acc = 0.4803, Val Loss = 0.6700, Val Acc = 0.9688
# Epoch 2: Train Loss = 10.5102, Train Acc = 0.7402, Val Loss = 0.6447, Val Acc = 0.6562
# Epoch 3: Train Loss = 10.3916, Train Acc = 0.6929, Val Loss = 0.6487, Val Acc = 0.8438
# Epoch 4: Train Loss = 10.0558, Train Acc = 0.7480, Val Loss = 0.6174, Val Acc = 0.7812
# Epoch 5: Train Loss = 10.0743, Train Acc = 0.6693, Val Loss = 0.6656, Val Acc = 0.4062
# Epoch 6: Train Loss = 9.6919, Train Acc = 0.7244, Val Loss = 0.5872, Val Acc = 0.8750
# Epoch 7: Train Loss = 9.9607, Train Acc = 0.6378, Val Loss = 0.6098, Val Acc = 0.6562
# Epoch 8: Train Loss = 9.4545, Train Acc = 0.6772, Val Loss = 0.6717, Val Acc = 0.4062
# Epoch 9: Train Loss = 9.2919, Train Acc = 0.7087, Val Loss = 0.6440, Val Acc = 0.4688
# Epoch 10: Train Loss = 8.6363, Train Acc = 0.7795, Val Loss = 0.5333, Val Acc = 0.8750
# Epoch 11: Train Loss = 8.3604, Train Acc = 0.7795, Val Loss = 0.5194, Val Acc = 0.7812
# Epoch 12: Train Loss = 7.9200, Train Acc = 0.8740, Val Loss = 0.4913, Val Acc = 0.7812
# Epoch 13: Train Loss = 7.2309, Train Acc = 0.9055, Val Loss = 0.4777, Val Acc = 0.7812
# Epoch 14: Train Loss = 7.4432, Train Acc = 0.8031, Val Loss = 0.4774, Val Acc = 0.7188
# Epoch 15: Train Loss = 8.1002, Train Acc = 0.7795, Val Loss = 0.5094, Val Acc = 0.9062
# Epoch 16: Train Loss = 8.7335, Train Acc = 0.6929, Val Loss = 0.5056, Val Acc = 0.8750
# Epoch 17: Train Loss = 7.7912, Train Acc = 0.7953, Val Loss = 0.4748, Val Acc = 1.0000
# Epoch 18: Train Loss = 7.3955, Train Acc = 0.8425, Val Loss = 0.6274, Val Acc = 0.6562
# Epoch 19: Train Loss = 7.6910, Train Acc = 0.8110, Val Loss = 0.4346, Val Acc = 1.0000
# Epoch 20: Train Loss = 6.4754, Train Acc = 0.9134, Val Loss = 0.4649, Val Acc = 0.7188

# %%
# Save Model
torch.save(model.state_dict(), "taglish_wpm_model.pth")

# %%
import speech_recognition as sr
import time

def classify_by_wpm(wpm):
    if wpm < 150:
        return "Least likely to have ADHD"
    elif 150 <= wpm <= 200:
        return "Moderately likely to have ADHD"
    else:
        return "Most likely to have ADHD"

r = sr.Recognizer()
session_text = ""
session_start = time.time()
max_session_duration = 5 * 60  # 5 minutes

with sr.Microphone() as source:
    print("🎙️ Start speaking (5-minute session)...")
    r.adjust_for_ambient_noise(source)

    try:
        while True:
            if time.time() - session_start > max_session_duration:
                break

            print("🎧 Listening for up to 15 seconds...")
            try:
                audio = r.listen(source, timeout=5, phrase_time_limit=15)
                text = r.recognize_google(audio, language="tl-PH")
                session_text += text + " "
                print("✅ Chunk Transcription:", text)
            except sr.WaitTimeoutError:
                print("⏳ Silence detected. Skipping chunk.")
            except sr.UnknownValueError:
                print("⚠️ Couldn't understand that chunk.")
            except sr.RequestError as e:
                print(f"❌ API error: {e}")
                break

    except KeyboardInterrupt:
        print("\n🛑 Manually stopped.")

# 📊 After session ends
end = time.time()
duration = end - session_start
duration_min = duration / 60
word_count = len(session_text.split())
wpm = word_count / duration_min if duration_min > 0 else 0
adhd_result = classify_by_wpm(wpm)

# ✅ Summary Output
print("\n📋 Final Summary:")
print("📄 Full Transcription:\n")
print(session_text.strip())

print("\n📊 Session Stats:")
print(f"⏱️ Duration: {duration:.2f} seconds")
print(f"🔢 Word Count: {word_count}")
print(f"🧮 Words Per Minute (WPM): {wpm:.2f}")
print(f"🧠 ADHD Likelihood: {adhd_result}")
# Out:
# 🎙️ Start speaking (5-minute session)...
# 🎧 Listening for up to 15 seconds...
# ✅ Chunk Transcription: ang konehot ang pagong Diabetes and the Turtle What's up panatimes Sa isang tahimik na kagubatan ay may dalawang
# 🎧 Listening for up to 15 seconds...
# ✅ Chunk Transcription: mabagal ngunit pa tiyaga sa isang araw nag-yabang sa koneho wala pang Mga talo sa akin sa karera
# 🎧 Listening for up to 15 seconds...
# ✅ Chunk Transcription: traffic ngumiti lang si pagong
# 🎧 Listening for up to 15 seconds...
# ✅ Chunk Transcription: magkaroon na tayo buk
# 🎧 Listening for up to 15 seconds...
# ✅ Chunk Transcription: ikoneho ang hamon kinabukasan nagsimula ang
# 🎧 Listening for up to 15 seconds...
# ✅ Chunk Transcription: tobilis na mabilis habang sa pagong ay dahan-dahan lang ang bagal niya Sabi ni koneho Matutulog muna ako
# 🎧 Listening for up to 15 seconds...
# ✅ Chunk Transcription: katulog habang si Kuneho tuloy-tuloy lang
# 🎧 Listening for up to 15 seconds...
# ✅ Chunk Transcription: habang tulog si koneho tuloy-tuloy lang si pagong mabagal pero hindi siya huminto pagkagising ikoneh
# 🎧 Listening for up to 15 seconds...
# ✅ Chunk Transcription: tumakbo siya agad pero huli na panalo na si pagong Mula noon nat
# 🎧 Listening for up to 15 seconds...
#
# 🛑 Manually stopped.
#
# 📋 Final Summary:
# 📄 Full Transcription:
#
# ang konehot ang pagong Diabetes and the Turtle What's up panatimes Sa isang tahimik na kagubatan ay may dalawang mabagal ngunit pa tiyaga sa isang araw nag-yabang sa koneho wala pang Mga talo sa akin sa karera traffic ngumiti lang si pagong magkaroon na tayo buk ikoneho ang hamon kinabukasan nagsimula ang tobilis na mabilis habang sa pagong ay dahan-dahan lang ang bagal niya Sabi ni koneho Matutulog muna ako katulog habang si Kuneho tuloy-tuloy lang habang tulog si koneho tuloy-tuloy lang si pagong mabagal pero hindi siya huminto pagkagising ikoneh tumakbo siya agad pero huli na panalo na si pagong Mula noon nat
#
# 📊 Session Stats:
# ⏱️ Duration: 67.98 seconds
# 🔢 Word Count: 104
# 🧮 Words Per Minute (WPM): 91.79
# 🧠 ADHD Likelihood: Least likely to have ADHD
